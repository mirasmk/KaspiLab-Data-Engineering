# %%
import pandas as pd
import sqlalchemy
from datetime import date

# %%
df = pd.read_csv("D:/Own Drive/all docs/сабак/Kaspi Lab Data Eng/hw13/5m Sales Records.csv", sep=",", encoding="utf-8")
df
# Out:
#                                Region           Country        Item Type  \
# 0               Australia and Oceania             Palau  Office Supplies
# 1                              Europe            Poland        Beverages
# 2                       North America            Canada           Cereal
# 3                              Europe           Belarus           Snacks
# 4        Middle East and North Africa              Oman           Cereal
# ...                               ...               ...              ...
# 4999995  Middle East and North Africa              Iraq        Household
# 4999996                        Europe            Monaco             Meat
# 4999997         Australia and Oceania   Solomon Islands          Clothes
# 4999998         Australia and Oceania  Marshall Islands        Cosmetics
# 4999999                        Europe            Greece  Office Supplies
#
#         Sales Channel Order Priority Order Date   Order ID   Ship Date  \
# ...

# %%
df['load_date'] = date.today().strftime("%d/%m/%Y")

# %%
def load_to_db():
    print("Loading table to db.")
    df.to_sql('stage_table', connection_to_db(), if_exists="append", method='multi', index=False, chunksize=1000)
    print("DONE")

# %%
def connection_to_db():
    engine = sqlalchemy.create_engine("mysql://codetest:swordfish@127.0.0.1:3306/codetest", encoding="utf-8", pool_pre_ping=True)
    connection = engine.connect()
    return connection

# %%
# %%time

load_to_db()
# Out:
# Loading table to db.
# DONE
# Wall time: 22min 10s

# %%
import mysql.connector

# %%
# %%time

db=mysql.connector.connect(host="127.0.0.1", user="codetest", password="swordfish", database="codetest")

cursor=db.cursor()

query="CREATE TABLE main_table SELECT * FROM stage_table"
cursor.execute(query)
# Out:
# Wall time: 2min 17s
